# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import pandas_datareader.data as web
import datetime

start_date = datetime.datetime(2012,1,1)
end_date = datetime.datetime.today()

ubisoft = web.DataReader('UBI.PA', 'yahoo', start_date, end_date)
ubisoft.tail()
# Out:
#                  High        Low       Open      Close    Volume  Adj Close
# Date
# 2020-12-02  79.400002  77.320000  79.099998  77.500000  484253.0  77.500000
# 2020-12-03  78.160004  76.360001  77.360001  76.620003  510294.0  76.620003
# 2020-12-04  78.260002  76.800003  76.820000  78.099998  401029.0  78.099998
# 2020-12-07  78.940002  76.959999  78.279999  77.800003  316831.0  77.800003
# 2020-12-08  79.400002  77.620003  77.760002  79.000000  332530.0  79.000000

# %%
ubisoft['Open'].plot(label='ubisoft', figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='Date'>
