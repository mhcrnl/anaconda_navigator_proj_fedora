# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import pandas_datareader.data as web
import datetime

start_date = datetime.datetime(2012,1,1)
end_date = datetime.datetime.today()

ford = web.DataReader('F', 'yahoo', start_date, end_date)
ford.tail()
# Out:
#             High   Low  Open  Close      Volume  Adj Close
# Date
# 2020-12-02  9.24  9.08  9.16   9.20  48345000.0       9.20
# 2020-12-03  9.32  9.15  9.26   9.21  50302100.0       9.21
# 2020-12-04  9.44  9.24  9.26   9.34  48775500.0       9.34
# 2020-12-07  9.33  9.15  9.31   9.22  58121000.0       9.22
# 2020-12-08  9.33  9.17  9.19   9.29  25574417.0       9.29

# %%
ford['Open'].plot(label='Ford', figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
ford['Volume'].plot(label='Ford', figsize=(16,8))
# Out:
# <AxesSubplot:xlabel='Date'>
